# %% [markdown]
# Aula 2 - Importação

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/imersao_python_acoes.xlsx", sheet_name = "Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação %  \
# 0           2.26         15.97      9.18      9.56  319,16 M        0.05
# 1         -12.11         50.56      6.66      6.86   32,65 M        0.02
# 2           7.64         77.55     40.81     42.34  436,69 M        0.02
# 3          -4.89         18.85     51.89     53.17  162,55 M        0.02
# 4          -3.66         20.70     36.37     37.32   73,42 M        0.02
# ..           ...           ...       ...       ...       ...         ...
# 76        -13.98        -32.72     10.70     11.08   38,19 M       -0.02
# 77        -23.55        -85.74      8.67      8.95   27,54 M       -0.02
# 78        -11.57         -2.77     56.04     58.90  624,74 M       -0.04
# 79        -12.29        -36.83      3.05      3.23  101,46 M       -0.04
# 80        -34.00        -25.44      5.51      6.02  154,36 M       -0.08
#
#     Valor Inicial (R$)  Quantidade de ações   Variação ($) Resultado  \
# 0                -9.01            515117391   254467991.15     Subiu
# 1                -6.66           1095462329   179305274.01     Subiu
# 2               -41.04           2379877655  2186926694.24     Subiu
# 3               -51.83            683452836   737694386.88     Subiu
# 4               -36.35           1814920980  1366871437.67     Subiu
# ..                 ...                  ...            ...       ...
# 76              -10.97           1110559345  -291405219.33    Desceu
# 77               -8.91           1420949112  -304111528.95    Desceu
# 78              -58.28           1218352541 -2487281332.68    Desceu
# 79               -3.20            525582771   -70350305.06    Desceu
# 80               -6.40            198184909   -94681651.17    Desceu
#
#      Nome da Empresa           Segmento  Idade         Cat Idade
# 0           Usiminas         Siderurgia     68    Entre 50 e 100
# 1      CSN Mineração          Mineração     83    Entre 50 e 100
# 2          Petrobras     Petróleo e Gás     71    Entre 50 e 100
# 3             Suzano   Papel e Celulose    100    Entre 50 e 100
# 4       CPFL Energia            Energia    112  Mais de 100 anos
# ..               ...                ...    ...               ...
# 76  Carrefour Brasil             Varejo     36       Menos de 50
# 77       Casas Bahia             Varejo     67    Entre 50 e 100
# 78          Localiza  Aluguel de Carros     51    Entre 50 e 100
# 79               CVC            Turismo     52    Entre 50 e 100
# 80               GOL   Transporte Aéreo     23       Menos de 50
#
# [81 rows x 20 columns]

# %%
df_total_acoes = pd.read_excel("/content/imersao_python_acoes.xlsx", sheet_name = "Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   235665566.00
# 1                      ALOS3   532616595.00
# 2                      ALPA4   176733968.00
# 3                      ABEV3  4394245879.00
# 4                      ARZZ3    62305891.00
# ..                       ...            ...
# 84                     VBBR3  1114412532.00
# 85                     WEGE3  1481593024.00
# 86                     YDUQ3   289347914.00
# 87  Quantidade Teórica Total 96372098181.00
# 88                   Redutor    17047850.79
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/imersao_python_acoes.xlsx", sheet_name = "Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/imersao_python_acoes.xlsx", sheet_name = "ChatGPT")
df_chatgpt
# Out:
#      Nome da Empresa           Segmento  Idade
# 0           Usiminas         Siderurgia     68
# 1      CSN Mineração          Mineração     83
# 2          Petrobras     Petróleo e Gás     71
# 3             Suzano   Papel e Celulose    100
# 4       CPFL Energia            Energia    112
# ..               ...                ...    ...
# 74  Carrefour Brasil             Varejo     36
# 75       Casas Bahia             Varejo     67
# 76          Localiza  Aluguel de Carros     51
# 77               CVC            Turismo     52
# 78               GOL   Transporte Aéreo     23
#
# [79 rows x 3 columns]

# %%
print(df_principal.columns)
# Out:
# Index(['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)', 'Var. Sem. (%)',
#        'Var. Mês (%)', 'Var. Ano (%)', 'Var. 12M (%)', 'Val. Mín', 'Val. Máx',
#        'Volume', 'Variação %', 'Valor Inicial (R$)', 'Quantidade de ações',
#        'Variação ($)', 'Resultado', 'Nome da Empresa', 'Segmento', 'Idade',
#        'Cat Idade'],
#       dtype='object')

# %%
df_principal = df_principal [['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final', 'Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] / 100
df_principal['valor_inicial'] = df_principal['valor_final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_total_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 7 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['valor_final'] - df_principal['valor_inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado              Nome
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_chatgpt
# Out:
#      Nome da Empresa           Segmento  Idade
# 0           Usiminas         Siderurgia     68
# 1      CSN Mineração          Mineração     83
# 2          Petrobras     Petróleo e Gás     71
# 3             Suzano   Papel e Celulose    100
# 4       CPFL Energia            Energia    112
# ..               ...                ...    ...
# 74  Carrefour Brasil             Varejo     36
# 75       Casas Bahia             Varejo     67
# 76          Localiza  Aluguel de Carros     51
# 77               CVC            Turismo     52
# 78               GOL   Transporte Aéreo     23
#
# [79 rows x 3 columns]

# %%
df_principal = df_principal.merge(df_chatgpt, left_on='Nome', right_on='Nome da Empresa', how='left')
df_principal = df_principal.drop(columns=['Nome da Empresa'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 78  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 79  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 80  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 81  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 82  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado              Nome           Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas         Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração          Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras     Petróleo e Gás
# 3     683452836   722946282.71     Subiu            Suzano   Papel e Celulose
# 4     187732538   138573955.06     Subiu      CPFL Energia            Energia
# ..          ...            ...       ...               ...                ...
# 78    533990587  -143635530.57    Desceu  Carrefour Brasil             Varejo
# 79     94843047   -20810240.84    Desceu       Casas Bahia             Varejo
# 80    853202347 -1807432634.46    Desceu          Localiza  Aluguel de Carros
# 81    525582771   -73557408.06    Desceu               CVC            Turismo
# 82    198184909  -102993202.62    Desceu               GOL   Transporte Aéreo
#
#     Idade
# 0      68
# 1      83
# 2      71
# 3     100
# 4     112
# ..    ...
# 78     36
# 79     67
# 80     51
# 81     52
# 82     23
#
# [83 rows x 12 columns]

# %%
df_principal['Cat_idade'] = df_principal['Idade'].apply(lambda x: 'Mais de 100' if x > 100 else ('Menos de 50' if x < 50 else 'Entre 50 e 100'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 78  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 79  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 80  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 81  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 82  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado              Nome           Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas         Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração          Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras     Petróleo e Gás
# 3     683452836   722946282.71     Subiu            Suzano   Papel e Celulose
# 4     187732538   138573955.06     Subiu      CPFL Energia            Energia
# ..          ...            ...       ...               ...                ...
# 78    533990587  -143635530.57    Desceu  Carrefour Brasil             Varejo
# 79     94843047   -20810240.84    Desceu       Casas Bahia             Varejo
# 80    853202347 -1807432634.46    Desceu          Localiza  Aluguel de Carros
# 81    525582771   -73557408.06    Desceu               CVC            Turismo
# 82    198184909  -102993202.62    Desceu               GOL   Transporte Aéreo
#
#     Idade       Cat_idade
# 0      68  Entre 50 e 100
# 1      83  Entre 50 e 100
# 2      71  Entre 50 e 100
# 3     100  Entre 50 e 100
# 4     112     Mais de 100
# ..    ...             ...
# 78     36     Menos de 50
# 79     67  Entre 50 e 100
# 80     51  Entre 50 e 100
# 81     52  Entre 50 e 100
# 82     23     Menos de 50
#
# [83 rows x 13 columns]

# %%
maior = df_principal['Variacao_rs'].max()

menor = df_principal['Variacao_rs'].min()

media = df_principal['Variacao_rs'].mean()

media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()

media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

print("Maior R$ {:,.2f}".format(maior))
print("Menor R$ {:,.2f}".format(menor))
print("Média R$ {:,.2f}".format(media))
print("Média de quem subiu R$ {:,.2f}".format(media_subiu))
print("Média de quem desceu R$ {:,.2f}".format(media_desceu))
# Out:
# Maior R$ 4,762,926,995.25
# Menor R$ -1,807,432,634.46
# Média R$ 172,006,927.65
# Média de quem subiu R$ 448,160,759.93
# Média de quem desceu R$ -181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 5   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 6   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 7   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 8   MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 9   ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 10  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 11  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 12  AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 13  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 14  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 15  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 16  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
# 17  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 18  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 19  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 20  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 21  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 22  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 23  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 24  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 25  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 26  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 27  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 28  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 29  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 30  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 31  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 32  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 33  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 34  BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 35  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 36  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 37  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 38  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 39  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 40  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 41  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 42  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 43  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 44  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 45  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
#
#     qtd_teorica   Variacao_rs Resultado                  Nome  \
# 0     515117391  241889725.43     Subiu              Usiminas
# 1    1110559345  177515970.30     Subiu         CSN Mineração
# 2    2379877655 2140059393.53     Subiu             Petrobras
# 3     683452836  722946282.71     Subiu                Suzano
# 4     187732538  138573955.06     Subiu          CPFL Energia
# 5     800010734  709687498.18     Subiu              PetroRio
# 6    4566445852 3103136291.22     Subiu             Petrobras
# 7    4196924316 4762926995.25     Subiu                  Vale
# 8     268505432  117732680.08     Subiu             Multiplan
# 9    4801593832 2297591984.33     Subiu         Itaú Unibanco
# 10   1168230366  453917907.01     Subiu             Rede D'Or
# 11    265877867   69054317.64     Subiu               Braskem
# 12    327593725   65452205.55     Subiu                  Azul
# 13    235665566   94204643.35     Subiu          3R Petroleum
# 14   1095587251  511671895.45     Subiu    Equatorial Energia
# 15    600865451  143220991.46     Subiu  Siderúrgica Nacional
# 16    289347914   72295838.99     Subiu                 YDUQS
# 17   1086411192  388705223.96     Subiu              Ultrapar
# 18    376187582   37525872.38     Subiu                   MRV
# 19     62305891   41021792.09     Subiu                Arezzo
# 20   5146576868  822148336.41     Subiu        Banco Bradesco
# 21   5146576868  822148336.41     Subiu        Banco Bradesco
# 22    261036182   18214628.10     Subiu               Minerva
# 23    159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 24   1677525446  233045769.57     Subiu                   BRF
# 25    423091712  188965307.06     Subiu                  Vivo
# 26   1218352541  229771333.63     Subiu                  Rumo
# 27   1095462329   43657683.38     Subiu                 Cielo
# 28    302768240   18068446.61     Subiu                 Dexco
# 29    807896814  103972807.37     Subiu                   TIM
# 30    251003438   42238249.54     Subiu             Bradespar
# 31    393173139   15598886.65     Subiu               Locaweb
# 32    275005663   46201006.00     Subiu        PetroRecôncavo
# 33   5372783971  373853994.88     Subiu                Itaúsa
# 34   1420949112  546752087.99     Subiu       Banco do Brasil
# 35   1275798515  202352473.74     Subiu          RaiaDrogasil
# 36    660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 37   1168097881  127229653.18     Subiu                 Cosan
# 38   1134986472  156573285.43     Subiu                   JBS
# 39   2867627068   28493619.27     Subiu        Magazine Luiza
# 40   1500728902   74019610.05     Subiu        Banco Bradesco
# 41   1500728902   74019610.05     Subiu        Banco Bradesco
# 42   1118525506   65779607.10     Subiu                Gerdau
# 43   1193047233   11571106.42     Subiu                Raízen
# 44   1679335290   32069789.50     Subiu                 Copel
# 45    421383330    4131341.16     Subiu           Grupo Vamos
#
#                     Segmento  Idade       Cat_idade
# 0                 Siderurgia     68  Entre 50 e 100
# 1                  Mineração     83  Entre 50 e 100
# 2             Petróleo e Gás     71  Entre 50 e 100
# 3           Papel e Celulose    100  Entre 50 e 100
# 4                    Energia    112     Mais de 100
# 5             Petróleo e Gás      9     Menos de 50
# 6             Petróleo e Gás     71  Entre 50 e 100
# 7                  Mineração     82  Entre 50 e 100
# 8           Shopping Centers     50  Entre 50 e 100
# 9           Setor Financeiro     16     Menos de 50
# 10                     Saúde     47     Menos de 50
# 11                   Química     22     Menos de 50
# 12          Transporte Aéreo     16     Menos de 50
# 13            Petróleo e Gás     10     Menos de 50
# 14                   Energia     25     Menos de 50
# 15                Siderurgia     83  Entre 50 e 100
# 16                  Educação     55  Entre 50 e 100
# 17                   Química     87  Entre 50 e 100
# 18          Construção Civil     45     Menos de 50
# 19           Moda e Calçados     52  Entre 50 e 100
# 20          Setor Financeiro     81  Entre 50 e 100
# 21          Setor Financeiro     81  Entre 50 e 100
# 22                 Alimentos    103     Mais de 100
# 23                    Varejo     76  Entre 50 e 100
# 24                 Alimentos     15     Menos de 50
# 25          Telecomunicações     26     Menos de 50
# 26                 Logística     16     Menos de 50
# 27          Setor Financeiro     29     Menos de 50
# 28                 Indústria     63  Entre 50 e 100
# 29          Telecomunicações     26     Menos de 50
# 30          Setor Financeiro     24     Menos de 50
# 31  Tecnologia da Informação     26     Menos de 50
# 32            Petróleo e Gás     12     Menos de 50
# 33          Setor Financeiro     58  Entre 50 e 100
# 34          Setor Financeiro    216     Mais de 100
# 35     Farmácias e Drogarias     13     Menos de 50
# 36                Siderurgia    123     Mais de 100
# 37  Energia e Infraestrutura     88  Entre 50 e 100
# 38                 Alimentos     71  Entre 50 e 100
# 39                    Varejo     67  Entre 50 e 100
# 40          Setor Financeiro     81  Entre 50 e 100
# 41          Setor Financeiro     81  Entre 50 e 100
# 42                Siderurgia    123     Mais de 100
# 43                   Energia     14     Menos de 50
# 44                   Energia     70  Entre 50 e 100
# 45                 Logística     55  Entre 50 e 100

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#                     Segmento   Variacao_rs
# 0                  Alimentos  407833683.09
# 1           Construção Civil   37525872.38
# 2                   Educação   72295838.99
# 3                    Energia  693886746.43
# 4   Energia e Infraestrutura  127229653.18
# 5      Farmácias e Drogarias  202352473.74
# 6                  Indústria   18068446.61
# 7                  Logística  233902674.79
# 8                  Mineração 4940442965.55
# 9            Moda e Calçados   41021792.09
# 10          Papel e Celulose  722946282.71
# 11            Petróleo e Gás 6093288832.26
# 12                   Química  457759541.59
# 13                     Saúde  453917907.01
# 14          Setor Financeiro 5096429893.05
# 15          Shopping Centers  117732680.08
# 16                Siderurgia  489935930.93
# 17  Tecnologia da Informação   15598886.65
# 18          Telecomunicações  292938114.42
# 19          Transporte Aéreo   65452205.55
# 20                    Varejo   34834535.50

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_rs
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 20615394956.61

# %%
fig = px.bar(df_analise_saldo, x = 'Resultado', y = 'Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
df_analise_saldo['Variacao_rs_formatado'] = df_analise_saldo['Variacao_rs'].map('{:,.2f}'.format)

fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs_formatado', title='Variação Reais por Resultado')

fig.update_yaxes(tickprefix='R$')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7791530f-e092-49ef-b98e-89bd98ef9b80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7791530f-e092-49ef-b98e-89bd98ef9b80")) {                    Plotly.newPlot(                        "7791530f-e092-49ef-b98e-89bd98ef9b80",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{y}\u003cbr\u003eVariacao_rs_formatado=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["-6,338,819,961.32","0.00","20,615,394,956.61"],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6338819961.31535,0.0,20615394956.60618],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"ove ...
